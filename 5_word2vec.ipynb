# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5241, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'as', 'of', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.075705
# Nearest to often: argentines, fmln, giulia, laughlin, capsule, hostname, stouffer, jains,
# Nearest to are: suck, confederacy, emitting, warlords, equals, tertullian, refuges, trusteeship,
# Nearest to d: caviar, apoplexy, dass, equus, wineries, inhibitors, repaid, porta,
# Nearest to up: pseudo, cjd, species, arid, happiness, lama, unbundling, christensen,
# Nearest to his: hydrology, luxuries, villas, regents, coursework, merger, moabite, premium,
# Nearest to in: sausages, moravian, refuges, rearranging, curb, turk, hepworth, abe,
# Nearest to can: juxtaposition, twelve, presentation, lungs, quays, disrupted, saddened, nicolay,
# Nearest to used: unlimited, vc, does, folks, catapult, bureaucracies, vipassana, anthropologists,
# Nearest to on: uss, travelling, psychotropic, pairings, troughs, copacabana, prophesy, camelopardalis,
# Nearest to between: replication, otimes, marseillaise, dodger, successes, vin, falsifiable, gainsborough,
# Nearest to for: crash, secundus, flea, spearheaded, thalberg, regents, northumbrian, avl,
# Nearest to years: pursuits, gallons, discouraged, mbe, surgeons, lh, cartel, enigma,
# Nearest to also: afb, nameless, lei, journalism, sweet, shellfish, clinics, owner,
# Nearest to four: pharaoh, numbered, atum, guise, scratches, destitute, gabbro, yoshi,
# Nearest to he: iranians, regimes, gernika, venezuela, dickie, understated, karmal, taverns,
# Nearest to known: resurrecting, semiconducting, vi, jutland, stoughton, basics, cer, lived,
# Average loss at step 2000: 4.367574
# Average loss at step 4000: 3.864019
# Average loss at step 6000: 3.787554
# Average loss at step 8000: 3.682135
# Average loss at step 10000: 3.614450
# Nearest to often: also, executors, caen, stouffer, giulia, basin, integral, hostname,
# Nearest to are: were, is, have, was, include, checks, hygiene, soso,
# Nearest to d: equus, rukh, algebra, canonic, praetor, gabriele, b, theodoret,
# Nearest to up: pseudo, out, operational, species, arid, news, contain, holley,
# Nearest to his: their, her, the, its, s, dysrhythmias, microseconds, subclass,
# Nearest to in: of, at, on, from, se, for, with, japanese,
# Nearest to can: may, will, would, could, lungs, presentation, frequently, groton,
# Nearest to used: vc, does, aster, duane, reddy, unlimited, perez, catapult,
# Nearest to on: in, after, following, by, from, at, into, looser,
# Nearest to between: marseillaise, dodger, from, replication, germain, otimes, vin, orientations,
# Nearest to for: in, of, with, portal, northumbrian, ptah, solidus, neq,
# Nearest to years: pursuits, coprime, organisational, gallons, wargames, brevity, sulfates, dumpling,
# Nearest to also: which, it, often, wingless, resists, honoured, what, headers,
# Nearest to four: six, eight, three, seven, five, nine, two, zero,
# Nearest to he: it, they, who, she, but, there, praying, elective,
# Nearest to known: vi, resurrecting, cer, eraserhead, drones, resolver, semiconducting, erfurt,
# Average loss at step 12000: 3.606074
# Average loss at step 14000: 3.576210
# Average loss at step 16000: 3.406069
# Average loss at step 18000: 3.456879
# Average loss at step 20000: 3.542968
# Nearest to often: also, executors, who, stouffer, sometimes, rosamund, still, muon,
# Nearest to are: were, is, have, include, was, hygiene, checks, be,
# Nearest to d: b, equus, maaouya, frederick, sint, discard, canonic, driver,
# Nearest to up: out, beets, operational, contain, arid, back, pseudo, him,
# Nearest to his: their, her, its, the, subclass, my, another, nuclei,
# Nearest to in: at, on, from, with, during, welded, se, for,
# Nearest to can: may, would, will, could, should, lungs, must, groton,
# Nearest to used: duane, known, backbone, reddy, agrarian, perez, vc, worshipped,
# Nearest to on: in, upon, at, into, during, through, cicero, exchanges,
# Nearest to between: from, with, marseillaise, dodger, teardrop, against, abi, afesd,
# Nearest to for: of, in, from, with, when, copycat, northumbrian, portal,
# Nearest to years: coprime, organisational, pursuits, dumpling, centuries, ribozymes, wargames, bello,
# Nearest to also: which, often, headers, now, that, what, traditionally, not,
# Nearest to four: seven, six, eight, five, three, two, nine, one,
# Nearest to he: it, they, she, who, there, narrowed, swelling, wildly,
# Nearest to known: used, vi, resurrecting, cer, such, dru, possible, eraserhead,
# Average loss at step 22000: 3.499573
# Average loss at step 24000: 3.490900
# Average loss at step 26000: 3.485120
# Average loss at step 28000: 3.482303
# Average loss at step 30000: 3.504097
# Nearest to often: sometimes, also, usually, still, executors, who, generally, frequently,
# Nearest to are: were, have, is, include, those, mature, perdition, br,
# Nearest to d: b, equus, maaouya, vane, frederick, rukh, pizan, driver,
# Nearest to up: out, back, him, them, beets, operational, off, truro,
# Nearest to his: her, their, its, the, s, undue, hugely, my,
# Nearest to in: on, under, at, during, of, from, with, se,
# Nearest to can: may, will, would, could, should, must, cannot, might,
# Nearest to used: known, found, called, backbone, croatia, written, duane, vc,
# Nearest to on: upon, in, into, from, at, through, under, against,
# Nearest to between: with, from, marseillaise, abi, in, against, mi, einer,
# Nearest to for: while, northumbrian, when, solidus, completing, with, speculators, to,
# Nearest to years: days, dumpling, coprime, organisational, centuries, times, ft, carolyn,
# Nearest to also: often, still, now, paces, headers, which, kw, wingless,
# Nearest to four: six, five, eight, three, seven, two, nine, zero,
# Nearest to he: it, she, they, who, there, never, wildly, later,
# Nearest to known: used, such, resurrecting, vi, well, possible, andean, cer,
# Average loss at step 32000: 3.502700
# Average loss at step 34000: 3.499939
# Average loss at step 36000: 3.453195
# Average loss at step 38000: 3.304240
# Average loss at step 40000: 3.431655
# Nearest to often: usually, sometimes, still, also, generally, who, actually, which,
# Nearest to are: were, include, is, have, be, but, distasteful, eurasia,
# Nearest to d: b, UNK, h, equus, sint, andy, j, v,
# Nearest to up: out, back, them, him, off, beets, truro, xxvi,
# Nearest to his: her, their, its, the, my, undue, s, dwan,
# Nearest to in: from, during, of, on, firepower, with, at, under,
# Nearest to can: may, could, will, would, should, must, might, cannot,
# Nearest to used: known, found, called, available, croatia, written, blockaded, classified,
# Nearest to on: upon, at, during, into, despite, in, against, abrams,
# Nearest to between: with, from, marseillaise, against, abi, dodger, einer, gollancz,
# Nearest to for: completing, if, maritimes, while, northumbrian, when, nineties, in,
# Nearest to years: days, centuries, times, months, decades, dumpling, organisational, coprime,
# Nearest to also: often, still, which, now, sometimes, paces, commonly, usually,
# Nearest to four: six, seven, three, five, eight, two, nine, one,
# Nearest to he: she, it, they, who, there, i, never, majors,
# Nearest to known: used, such, called, andean, vi, possible, regarded, served,
# Average loss at step 42000: 3.432364
# Average loss at step 44000: 3.457320
# Average loss at step 46000: 3.447699
# Average loss at step 48000: 3.357103
# Average loss at step 50000: 3.381822
# Nearest to often: sometimes, usually, generally, still, also, frequently, which, now,
# Nearest to are: were, is, have, include, those, being, be, these,
# Nearest to d: b, h, sint, v, j, m, p, r,
# Nearest to up: out, off, back, them, him, down, truro, projectile,
# Nearest to his: her, their, its, my, undue, displeased, your, the,
# Nearest to in: during, from, on, since, of, at, between, within,
# Nearest to can: may, could, will, would, should, must, might, cannot,
# Nearest to used: known, written, seen, found, available, called, referred, given,
# Nearest to on: upon, in, at, through, during, against, under, regarding,
# Nearest to between: with, in, from, around, dodger, einer, within, against,
# Nearest to for: while, maritimes, including, sumter, salle, sopwith, if, trainees,
# Nearest to years: days, times, decades, months, centuries, dumpling, organisational, weeks,
# Nearest to also: often, which, still, now, then, subsequently, here, who,
# Nearest to four: six, five, eight, seven, three, nine, two, zero,
# Nearest to he: she, it, they, who, there, i, never, eventually,
# Nearest to known: used, such, regarded, served, called, possible, andean, defined,
# Average loss at step 52000: 3.437947
# Average loss at step 54000: 3.426448
# Average loss at step 56000: 3.441575
# Average loss at step 58000: 3.397291
# Average loss at step 60000: 3.393269
# Nearest to often: sometimes, usually, generally, still, commonly, also, frequently, now,
# Nearest to are: were, have, is, include, be, swung, these, hygiene,
# Nearest to d: b, p, h, r, v, mediocre, sint, equus,
# Nearest to up: out, off, back, them, down, him, xxvi, technetium,
# Nearest to his: her, their, its, my, the, undue, hugely, paula,
# Nearest to in: during, within, lyceum, since, including, of, at, among,
# Nearest to can: may, could, would, will, should, must, might, cannot,
# Nearest to used: known, written, seen, found, called, available, held, considered,
# Nearest to on: upon, under, scrambled, cicero, through, awhile, with, in,
# Nearest to between: with, among, around, against, within, abi, from, dodger,
# Nearest to for: including, of, northumbrian, if, without, maritimes, although, solidus,
# Nearest to years: days, decades, times, centuries, months, seconds, weeks, hours,
# Nearest to also: now, still, often, usually, which, commonly, spins, sometimes,
# Nearest to four: five, six, eight, three, seven, nine, zero, two,
# Nearest to he: she, it, they, there, who, eventually, never, later,
# Nearest to known: used, such, regarded, possible, served, called, andean, defined,
# Average loss at step 62000: 3.240489
# Average loss at step 64000: 3.255602
# Average loss at step 66000: 3.407832
# Average loss at step 68000: 3.392114
# Average loss at step 70000: 3.357861
# Nearest to often: sometimes, usually, generally, still, frequently, also, commonly, actually,
# Nearest to are: were, is, have, include, while, be, although, those,
# Nearest to d: b, p, v, andy, h, pathos, equus, sint,
# Nearest to up: out, off, back, them, down, him, jenner, technetium,
# Nearest to his: her, their, its, my, displeased, undue, your, our,
# Nearest to in: within, during, on, lyceum, into, at, of, from,
# Nearest to can: may, could, would, will, should, must, might, cannot,
# Nearest to used: known, written, seen, found, considered, called, referred, described,
# Nearest to on: upon, in, through, within, via, at, under, cicero,
# Nearest to between: with, among, around, within, from, in, against, abi,
# Nearest to for: without, including, northumbrian, while, in, completing, against, of,
# Nearest to years: days, decades, months, times, hours, centuries, minutes, weeks,
# Nearest to also: still, often, which, now, never, usually, sometimes, occasionally,
# Nearest to four: six, three, five, seven, eight, zero, nine, two,
# Nearest to he: she, it, they, there, eventually, who, we, later,
# Nearest to known: used, regarded, such, seen, defined, called, served, possible,
# Average loss at step 72000: 3.372859
# Average loss at step 74000: 3.344483
# Average loss at step 76000: 3.316977
# Average loss at step 78000: 3.355633
# Average loss at step 80000: 3.379450
# Nearest to often: sometimes, usually, generally, commonly, still, frequently, also, now,
# Nearest to are: were, include, have, is, be, those, swung, although,
# Nearest to d: b, p, f, sint, pathos, v, andy, h,
# Nearest to up: out, off, back, them, down, jenner, technetium, sclc,
# Nearest to his: her, their, its, my, your, displeased, undue, our,
# Nearest to in: during, on, at, within, until, since, of, padres,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to used: known, written, seen, referred, found, called, considered, described,
# Nearest to on: upon, in, through, during, via, at, under, wolfenstein,
# Nearest to between: with, among, within, around, concerning, gwynne, through, macrinus,
# Nearest to for: including, against, while, solidus, troubadors, northumbrian, massawa, without,
# Nearest to years: days, decades, months, times, centuries, minutes, hours, weeks,
# Nearest to also: often, still, now, which, sometimes, usually, currently, never,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to he: she, it, they, there, who, eventually, we, later,
# Nearest to known: used, regarded, called, possible, defined, considered, seen, such,
# Average loss at step 82000: 3.403602
# Average loss at step 84000: 3.407057
# Average loss at step 86000: 3.393886
# Average loss at step 88000: 3.352687
# Average loss at step 90000: 3.366619
# Nearest to often: sometimes, usually, generally, commonly, frequently, still, also, actually,
# Nearest to are: were, is, include, these, have, although, famously, allotrope,
# Nearest to d: b, norris, sint, bw, p, passengers, pathos, appropriately,
# Nearest to up: out, off, back, them, down, him, together, percussionist,
# Nearest to his: her, their, its, my, your, our, displeased, the,
# Nearest to in: during, with, under, at, lyceum, within, liberia, of,
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to used: known, seen, written, considered, referred, given, described, applied,
# Nearest to on: upon, under, through, at, against, via, during, scrambled,
# Nearest to between: with, among, within, around, concerning, against, abi, from,
# Nearest to for: without, after, including, of, while, against, completing, northumbrian,
# Nearest to years: days, decades, months, hours, year, minutes, weeks, centuries,
# Nearest to also: now, still, often, never, sometimes, actually, which, traditionally,
# Nearest to four: seven, five, six, eight, two, three, nine, one,
# Nearest to he: she, it, they, there, who, eventually, later, we,
# Nearest to known: used, regarded, such, called, possible, seen, described, served,
# Average loss at step 92000: 3.400253
# Average loss at step 94000: 3.254507
# Average loss at step 96000: 3.360543
# Average loss at step 98000: 3.242003
# Average loss at step 100000: 3.356223
# Nearest to often: sometimes, usually, generally, commonly, frequently, still, typically, now,
# Nearest to are: were, include, those, these, have, is, while, be,
# Nearest to d: b, sint, oxidizes, f, passengers, andy, pathos, c,
# Nearest to up: out, off, back, them, down, him, together, technetium,
# Nearest to his: her, their, my, your, its, our, the, displeased,
# Nearest to in: during, within, on, throughout, from, at, into, refuelling,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to used: seen, known, written, considered, referred, found, employed, given,
# Nearest to on: upon, through, in, under, via, at, against, into,
# Nearest to between: with, around, among, concerning, within, against, einer, seaport,
# Nearest to for: northumbrian, without, before, including, solidus, after, allomorphy, against,
# Nearest to years: days, decades, months, hours, year, minutes, weeks, centuries,
# Nearest to also: now, still, never, actually, sometimes, often, below, which,
# Nearest to four: five, seven, eight, six, three, two, nine, zero,
# Nearest to he: she, it, they, there, who, we, never, eventually,
# Nearest to known: used, such, possible, regarded, seen, defined, available, described,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# The CBOW model predicts the word from context. On the other hand, the skip gram model learns to predict the context given a word. The CBOW model can be implemented by simply interchanging `batch_labels` with `batch_data`.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_labels, batch_data = generate_batch(
      batch_size, num_skips, skip_window)
    batch_labels = np.reshape(batch_labels,(batch_labels.shape[0],1))
    batch_data = np.reshape(batch_data,(batch_data.shape[0]))
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.089706
# Nearest to often: glibc, capitalists, toccata, pizzicato, retire, pranks, taxonomy, motionless,
# Nearest to are: accounted, thoth, tanner, woodwind, domino, office, comrade, rhea,
# Nearest to d: burnside, linkage, gorge, coms, toot, geelong, pont, rental,
# Nearest to up: ethers, penitentiary, taiwan, southwest, barking, windsurfing, driver, breakdown,
# Nearest to his: mckean, yin, pakistanis, irrationality, dorms, payne, canyon, locates,
# Nearest to in: solicitation, moslem, iai, herbal, mistress, calcutta, huey, avro,
# Nearest to can: creditors, sheppard, pid, volatility, alloy, fukuoka, generality, tour,
# Nearest to used: tendons, pinyin, privy, lust, asteraceae, daimlerchrysler, cornerstone, dislike,
# Nearest to on: nationalisation, resins, cauldron, worm, moines, conceded, pete, disposition,
# Nearest to between: southerner, butterfield, producer, disbandment, reviewers, dialect, employer, romances,
# Nearest to for: baggage, ken, characterises, reruns, lore, quran, rajons, melvins,
# Nearest to years: majuro, loses, bunkers, adjoined, tryptophan, diffusing, abridged, sardar,
# Nearest to also: lifecycle, galina, horne, doomsday, psych, eapc, klan, amoeba,
# Nearest to four: welcoming, incorporation, pdas, medici, varnothing, predicated, cubans, posix,
# Nearest to he: manga, faithful, readability, rh, tib, switzer, volcano, rating,
# Nearest to known: sustains, prospective, garonne, farian, bipm, brava, ramsey, subjective,
# Average loss at step 2000: 4.381042
# Average loss at step 4000: 3.878392
# Average loss at step 6000: 3.800070
# Average loss at step 8000: 3.759498
# Average loss at step 10000: 3.622625
# Nearest to often: also, toccata, plucking, dough, flynn, mb, klondike, decapitation,
# Nearest to are: were, is, have, was, toms, by, tanner, gazetteer,
# Nearest to d: b, burnside, etiology, linkage, pont, toot, ietf, gorge,
# Nearest to up: spreadsheets, grouped, windsurfing, penitentiary, millimetre, apache, spaceship, taiwan,
# Nearest to his: their, the, s, mckean, caring, tamils, especially, awakening,
# Nearest to in: on, from, of, and, by, with, for, galatea,
# Nearest to can: would, may, should, could, will, cannot, doped, must,
# Nearest to used: known, privy, lust, tendons, daoxuan, cornerstone, unhelpful, santorum,
# Nearest to on: in, by, from, bloomsbury, erc, with, and, for,
# Nearest to between: from, calvi, enumerable, subsidised, toolkit, in, airway, containment,
# Nearest to for: and, in, with, of, by, is, griese, on,
# Nearest to years: deprecating, selig, forgotten, tryptophan, palms, clausewitz, cast, ventspils,
# Nearest to also: often, which, it, who, that, usually, legalisation, sometimes,
# Nearest to four: five, three, six, eight, seven, zero, nine, two,
# Nearest to he: it, she, they, there, marat, bader, rainbows, analyzer,
# Nearest to known: well, used, sustains, brava, prospective, farian, pedantic, eliminate,
# Average loss at step 12000: 3.585910
# Average loss at step 14000: 3.619434
# Average loss at step 16000: 3.583567
# Average loss at step 18000: 3.571763
# Average loss at step 20000: 3.551277
# Nearest to often: also, generally, commonly, widely, usually, sometimes, dough, plucking,
# Nearest to are: were, have, is, be, include, these, while, toms,
# Nearest to d: b, cdot, burnside, whenever, scavengers, sapphire, shuttlecock, coms,
# Nearest to up: grouped, out, penitentiary, millimetre, her, apache, windsurfing, germinate,
# Nearest to his: their, her, its, the, my, s, ilinden, caring,
# Nearest to in: on, at, of, for, from, during, and, with,
# Nearest to can: may, would, will, could, should, must, might, cannot,
# Nearest to used: known, found, brandon, considered, slugging, corso, santorum, temporally,
# Nearest to on: in, bloomsbury, at, erc, during, generating, mashing, against,
# Nearest to between: with, from, in, subsidised, calvi, cumont, revolted, redaction,
# Nearest to for: in, to, by, through, rajons, lex, at, from,
# Nearest to years: deprecating, palms, tryptophan, times, months, forgotten, frontal, days,
# Nearest to also: often, sometimes, which, germline, usually, now, who, not,
# Nearest to four: five, seven, six, eight, three, nine, two, zero,
# Nearest to he: she, it, they, who, there, bader, marat, dramatically,
# Nearest to known: well, used, sustains, defined, prospective, described, pedantic, brava,
# Average loss at step 22000: 3.521547
# Average loss at step 24000: 3.446051
# Average loss at step 26000: 3.421560
# Average loss at step 28000: 3.473371
# Average loss at step 30000: 3.408131
# Nearest to often: also, sometimes, usually, generally, commonly, widely, now, zagros,
# Nearest to are: were, have, is, include, be, require, gazetteer, canonic,
# Nearest to d: b, cdot, and, whenever, undertakings, burnside, scavengers, duckburg,
# Nearest to up: out, grouped, them, apache, him, millimetre, windsurfing, penitentiary,
# Nearest to his: her, their, the, its, my, dhabi, dire, lawyer,
# Nearest to in: at, on, during, of, from, under, with, between,
# Nearest to can: may, would, will, could, must, should, cannot, might,
# Nearest to used: known, found, considered, seen, available, defined, required, responsible,
# Nearest to on: in, at, upon, during, nieces, lpc, with, mashing,
# Nearest to between: from, with, among, in, subsidised, calvi, redaction, destruct,
# Nearest to for: unprovoked, griese, debugging, at, rajons, by, characterise, in,
# Nearest to years: days, months, times, year, deprecating, palms, tryptophan, frontal,
# Nearest to also: often, sometimes, now, which, usually, germline, it, still,
# Nearest to four: six, five, three, seven, eight, two, zero, nine,
# Nearest to he: she, it, they, who, there, prion, later, bader,
# Nearest to known: well, used, described, defined, such, prospective, glibc, possible,
# Average loss at step 32000: 3.419589
# Average loss at step 34000: 3.441332
# Average loss at step 36000: 3.365930
# Average loss at step 38000: 3.497578
# Average loss at step 40000: 3.447382
# Nearest to often: sometimes, usually, generally, commonly, widely, also, still, now,
# Nearest to are: were, is, have, include, require, trujillo, do, be,
# Nearest to d: b, cdot, petal, whenever, undertakings, jass, grapple, bains,
# Nearest to up: out, him, grouped, apache, them, down, studi, windsurfing,
# Nearest to his: their, her, its, my, the, s, whose, dhabi,
# Nearest to in: during, galatea, within, at, until, moslem, under, from,
# Nearest to can: may, will, would, could, must, should, cannot, might,
# Nearest to used: found, known, seen, considered, available, called, defined, described,
# Nearest to on: during, upon, around, in, erc, about, lpc, generating,
# Nearest to between: with, from, among, during, against, cumont, subsidised, under,
# Nearest to for: after, against, including, without, while, peloponnesus, before, within,
# Nearest to years: days, times, months, year, deprecating, places, decades, minutes,
# Nearest to also: often, now, usually, sometimes, still, which, germline, simply,
# Nearest to four: five, six, three, seven, eight, two, zero, nine,
# Nearest to he: she, it, they, who, there, prion, interpretative, dramatically,
# Nearest to known: well, described, such, used, defined, seen, possible, regarded,
# Average loss at step 42000: 3.425200
# Average loss at step 44000: 3.275243
# Average loss at step 46000: 3.411405
# Average loss at step 48000: 3.431271
# Average loss at step 50000: 3.435781
# Nearest to often: usually, sometimes, generally, also, commonly, widely, still, typically,
# Nearest to are: were, is, have, include, be, although, require, these,
# Nearest to d: b, cdot, whenever, t, grapple, petal, fula, r,
# Nearest to up: out, down, him, them, apache, grouped, studi, penitentiary,
# Nearest to his: their, her, its, my, the, our, whose, your,
# Nearest to in: during, since, of, from, within, until, at, between,
# Nearest to can: may, would, will, could, must, should, cannot, might,
# Nearest to used: known, found, considered, available, seen, required, responsible, referred,
# Nearest to on: upon, during, through, about, around, under, generating, disassembly,
# Nearest to between: with, in, among, from, subsidised, under, cumont, over,
# Nearest to for: after, including, without, in, influencing, against, debugging, of,
# Nearest to years: days, months, times, year, places, decades, deprecating, minutes,
# Nearest to also: often, now, sometimes, usually, still, which, generally, germline,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to he: she, it, they, who, there, we, dramatically, never,
# Nearest to known: used, defined, such, described, well, possible, seen, regarded,
# Average loss at step 52000: 3.452523
# Average loss at step 54000: 3.434609
# Average loss at step 56000: 3.405479
# Average loss at step 58000: 3.282323
# Average loss at step 60000: 3.382456
# Nearest to often: usually, sometimes, generally, commonly, also, widely, still, frequently,
# Nearest to are: were, is, include, have, be, although, bosch, those,
# Nearest to d: b, cdot, whenever, t, grapple, karo, chamada, boogie,
# Nearest to up: out, down, him, them, back, grouped, apache, penitentiary,
# Nearest to his: her, their, my, its, your, the, our, whose,
# Nearest to in: on, during, at, within, from, until, since, near,
# Nearest to can: could, may, will, would, must, should, cannot, might,
# Nearest to used: considered, known, found, available, referred, responsible, seen, called,
# Nearest to on: in, upon, generating, through, during, around, against, meanwhile,
# Nearest to between: with, among, from, into, subsidised, over, within, southerner,
# Nearest to for: against, without, while, after, including, within, by, peloponnesus,
# Nearest to years: days, months, times, year, decades, minutes, weeks, places,
# Nearest to also: often, now, still, sometimes, which, usually, who, generally,
# Nearest to four: six, five, eight, three, seven, two, nine, one,
# Nearest to he: she, it, they, there, who, then, interpretative, we,
# Nearest to known: used, such, defined, possible, considered, regarded, described, well,
# Average loss at step 62000: 3.443804
# Average loss at step 64000: 3.360211
# Average loss at step 66000: 3.344265
# Average loss at step 68000: 3.385055
# Average loss at step 70000: 3.373164
# Nearest to often: sometimes, usually, generally, commonly, still, widely, also, frequently,
# Nearest to are: were, is, have, although, require, include, those, toms,
# Nearest to d: b, cdot, whenever, t, boogie, karo, grapple, petal,
# Nearest to up: out, him, down, them, grouped, back, again, studi,
# Nearest to his: her, their, its, my, your, the, whose, our,
# Nearest to in: during, on, at, until, within, since, through, from,
# Nearest to can: will, could, would, must, may, should, cannot, might,
# Nearest to used: known, considered, found, described, referred, available, responsible, seen,
# Nearest to on: upon, through, in, around, during, generating, against, at,
# Nearest to between: with, among, in, over, from, during, into, against,
# Nearest to for: after, against, jacobs, while, with, without, although, despite,
# Nearest to years: days, months, year, times, minutes, decades, weeks, places,
# Nearest to also: now, often, still, sometimes, which, usually, never, already,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to he: she, it, they, there, who, prion, interpretative, never,
# Nearest to known: used, defined, such, regarded, well, possible, described, considered,
# Average loss at step 72000: 3.401628
# Average loss at step 74000: 3.390603
# Average loss at step 76000: 3.348038
# Average loss at step 78000: 3.236905
# Average loss at step 80000: 3.376966
# Nearest to often: usually, sometimes, generally, commonly, still, also, frequently, typically,
# Nearest to are: were, have, is, include, be, those, included, require,
# Nearest to d: b, t, whenever, grapple, cdot, boogie, molybdenum, tt,
# Nearest to up: out, down, them, him, off, back, together, studi,
# Nearest to his: her, their, your, my, its, our, the, whose,
# Nearest to in: during, of, at, since, on, within, artefacts, between,
# Nearest to can: may, will, could, would, must, should, cannot, might,
# Nearest to used: found, available, called, known, considered, responsible, written, required,
# Nearest to on: upon, through, against, in, by, during, around, generating,
# Nearest to between: with, among, during, against, from, within, in, zeit,
# Nearest to for: of, against, if, after, while, with, without, unprovoked,
# Nearest to years: days, months, year, times, decades, minutes, weeks, places,
# Nearest to also: often, now, still, which, sometimes, usually, never, isomorphic,
# Nearest to four: five, six, three, seven, eight, nine, zero, two,
# Nearest to he: she, it, they, there, who, we, prion, interpretative,
# Nearest to known: used, defined, possible, called, described, regarded, seen, such,
# Average loss at step 82000: 3.297468
# Average loss at step 84000: 3.341293
# Average loss at step 86000: 3.347797
# Average loss at step 88000: 3.321065
# Average loss at step 90000: 3.248384
# Nearest to often: usually, sometimes, generally, commonly, still, also, frequently, typically,
# Nearest to are: were, is, include, have, these, although, was, those,
# Nearest to d: b, grapple, klein, chattanooga, secondo, petal, hur, undertakings,
# Nearest to up: out, down, him, them, off, together, back, grouped,
# Nearest to his: her, their, its, my, your, our, antitrust, the,
# Nearest to in: during, at, within, until, throughout, on, near, of,
# Nearest to can: could, will, may, must, should, would, cannot, might,
# Nearest to used: known, found, referred, available, described, considered, applied, required,
# Nearest to on: upon, around, in, through, generating, during, about, erc,
# Nearest to between: among, with, against, around, from, through, containment, electroweak,
# Nearest to for: after, nagel, rajons, diffusing, against, syngman, while, internationale,
# Nearest to years: days, months, year, decades, minutes, weeks, times, centuries,
# Nearest to also: often, now, still, sometimes, never, which, who, usually,
# Nearest to four: five, three, seven, six, eight, nine, two, zero,
# Nearest to he: she, it, they, there, who, prion, but, even,
# Nearest to known: used, defined, described, possible, seen, such, regarded, called,
# Average loss at step 92000: 2.740885
# Average loss at step 94000: 3.103898
# Average loss at step 96000: 3.073085
# Average loss at step 98000: 3.223921
# Average loss at step 100000: 3.278216
# Nearest to often: usually, sometimes, generally, commonly, also, frequently, typically, still,
# Nearest to are: were, is, have, those, include, these, toms, contain,
# Nearest to d: b, petal, unsafe, etiology, boogie, bunny, chattanooga, tarn,
# Nearest to up: out, down, off, them, him, back, together, studi,
# Nearest to his: her, their, its, my, your, whose, the, our,
# Nearest to in: within, during, throughout, at, since, for, between, groupe,
# Nearest to can: could, must, will, may, should, would, cannot, might,
# Nearest to used: known, found, referred, called, described, applied, seen, required,
# Nearest to on: upon, around, generating, about, in, through, against, dated,
# Nearest to between: with, among, against, within, through, in, containment, from,
# Nearest to for: after, without, by, in, including, against, of, rajons,
# Nearest to years: days, months, year, decades, weeks, minutes, times, centuries,
# Nearest to also: often, now, still, sometimes, never, already, traditionally, which,
# Nearest to four: five, six, seven, eight, three, nine, zero, two,
# Nearest to he: she, it, they, there, prion, but, who, starbuck,
# Nearest to known: used, possible, regarded, seen, defined, such, described, called,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
